# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
#membaca data
img = cv2.imread('einstaint.png')

#membuat rotasi
(h, w) = img.shape[:2]
center = (w // 2, h // 2)
M = cv2.getRotationMatrix2D(center, 45, 1.0)
rotated = cv2.warpAffine(img, M, (w, h))

#membuat size
resized = cv2.resize(img, (0, 0), fx=0.1, fy=0.2)

#membuat crop
cropped = img[150:150+300, 100:100+200]

#membuat flip
flipped = cv2.flip(img, 1)

#membuat bingkai
(h, w) = img.shape[:2]
M = np.float32([[1, 0, 50], [0, 1, 25]])
Translated = cv2.warpAffine(img, M, (w, h))

# TAMPILAN MENGGUNAKAN FIGUR DAN XIS (FUNGSI MATPLOTLIB)
fig, axs = plt.subplots(2, 3, figsize=(15, 10))
ax = axs.ravel()

# Tampilan Asli
ax[0].imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
ax[0].set_title ('Citra Asli')

# Tampilan edges
ax[1].imshow(cv2.cvtColor(rotated, cv2.COLOR_BGR2RGB))
ax[1].set_title ('After Rotated')

# Tampilan edges
ax[2].imshow(cv2.cvtColor(resized, cv2.COLOR_BGR2RGB))
ax[2].set_title ('After Resized')

ax[3].imshow(cv2.cvtColor(cropped, cv2.COLOR_BGR2RGB))
ax[3].set_title ('After Cropped')

ax[4].imshow(cv2.cvtColor(flipped, cv2.COLOR_BGR2RGB))
ax[4].set_title ('After Flipped')

ax[5].imshow(cv2.cvtColor(Transformasi, cv2.COLOR_BGR2RGB))
ax[5].set_title ('After Translated')
# Out:
# Text(0.5, 1.0, 'After Translated')
